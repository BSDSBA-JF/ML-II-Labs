# %%
import pandas as pd

# %% [markdown]
# # Setting a Baseline - Just do Logistic Regression

# %% [markdown]
# Just use the data below and then create separate KNN models for each target variable, which are:
# 1. Fielder-Type (binary where a character can only be an on or off fielder)
# 2. DPS (binary)
# 3. Support (binary)
# 4. Survivability (binary)

# %%
pd.read_csv('data/cleaned_node.csv')
# Out:
#                name   element             weaponType     region  \
# 0    Kamisato Ayaka       Ice  WEAPON_SWORD_ONE_HAND    INAZUMA
# 1              Jean      Wind  WEAPON_SWORD_ONE_HAND  MONDSTADT
# 2              Lisa  Electric        WEAPON_CATALYST  MONDSTADT
# 3           Barbara     Water        WEAPON_CATALYST  MONDSTADT
# 4             Kaeya       Ice  WEAPON_SWORD_ONE_HAND  MONDSTADT
# ..              ...       ...                    ...        ...
# 100          Ineffa  Electric            WEAPON_POLE    NODKRAI
# 101           Lauma     Grass        WEAPON_CATALYST    NODKRAI
# 102           Flins  Electric            WEAPON_POLE    NODKRAI
# 103            Aino     Water        WEAPON_CLAYMORE    NODKRAI
# 104           Nefer     Grass        WEAPON_CATALYST    NODKRAI
#
#                       specialProp bodyType  Element  On-Field  Off-Field  \
# 0        FIGHT_PROP_CRITICAL_HURT     GIRL     Cryo         1          0
# 1             FIGHT_PROP_HEAL_ADD     LADY    Anemo         0          1
# 2      FIGHT_PROP_ELEMENT_MASTERY     LADY  Electro         0          1
# 3           FIGHT_PROP_HP_PERCENT     GIRL    Hydro         0          1
# 4    FIGHT_PROP_CHARGE_EFFICIENCY     MALE     Cryo         0          1
# ..                            ...      ...      ...       ...        ...
# 100           FIGHT_PROP_CRITICAL     GIRL  Electro         0          1
# 101    FIGHT_PROP_ELEMENT_MASTERY     LADY   Dendro         0          1
# 102      FIGHT_PROP_CRITICAL_HURT     MALE  Electro         1          0
# 103    FIGHT_PROP_ELEMENT_MASTERY     LOLI    Hydro         0          1
# 104      FIGHT_PROP_CRITICAL_HURT     LADY   Dendro         1          0
#
#     Fielder-Type  DPS  Support  Survivability
# 0       On-Field    1        0              0
# 1      Off-Field    0        0              1
# 2      Off-Field    1        0              0
# 3      Off-Field    0        0              1
# 4      Off-Field    1        0              0
# ..           ...  ...      ...            ...
# 100    Off-Field    1        0              1
# 101    Off-Field    0        1              0
# 102     On-Field    1        0              0
# 103    Off-Field    1        0              0
# 104     On-Field    1        0              0
#
# [105 rows x 13 columns]
