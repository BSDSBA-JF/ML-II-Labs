# %%
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
folder_path = '/mnt/data/public/food-com-recipes/RAW_recipes.csv'
df = pd.read_csv(folder_path)
df['nutrition'] = df['nutrition'].apply(json.loads)

# %%
relevant_columns = ['name', 'id', 'minutes','tags', 'nutrition', 'ingredients']
nutrition_cols = ['calories', 'total_fat_PDV', 'sugar_PDV', 'sodium_PDV', 
                  'protein_PDV', 'saturated_fat_PDV', 'carbohydrates_PDV']

#df_nutrition = pd.DataFrame(df['nutrition'].tolist(), columns=nutrition_cols)

# %%
df_nutritions = df['nutrition'].apply(pd.Series)
df_nutritions.columns = nutrition_cols
df_nutritions
# Out:
#         calories  total_fat_PDV  sugar_PDV  sodium_PDV  protein_PDV  \
# 0           51.5            0.0       13.0         0.0          2.0
# 1          173.4           18.0        0.0        17.0         22.0
# 2          269.8           22.0       32.0        48.0         39.0
# 3          368.1           17.0       10.0         2.0         14.0
# 4          352.9            1.0      337.0        23.0          3.0
# ...          ...            ...        ...         ...          ...
# 231632     415.2           26.0       34.0        26.0         44.0
# 231633      14.8            0.0        2.0        58.0          1.0
# 231634      59.2            6.0        2.0         3.0          6.0
# 231635     188.0           11.0       57.0        11.0          7.0
# 231636     174.9           14.0       33.0         4.0          4.0
#
#         saturated_fat_PDV  carbohydrates_PDV
# 0                     0.0                4.0
# 1                    35.0                1.0
# ...

# %%
df_nutritions.hist(figsize=(12, 12))
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad: 'float' = 1.08, h_pad: 'float | None' = None, w_pad: 'float | None' = None, rect: 'tuple[float, float, float, float] | None' = None) -> 'None'>

# %%
df_nutritions.describe()
# Out:
#             calories  total_fat_PDV      sugar_PDV     sodium_PDV  \
# count  231637.000000   231637.00000  231637.000000  231637.000000
# mean      473.942425       36.08070      84.296865      30.147485
# std      1189.711374       77.79884     800.080897     131.961589
# min         0.000000        0.00000       0.000000       0.000000
# 25%       174.400000        8.00000       9.000000       5.000000
# 50%       313.400000       20.00000      25.000000      14.000000
# 75%       519.700000       41.00000      68.000000      33.000000
# max    434360.200000    17183.00000  362729.000000   29338.000000
#
#         protein_PDV  saturated_fat_PDV  carbohydrates_PDV
# count  231637.00000      231637.000000      231637.000000
# mean       34.68186          45.589150          15.560403
# std        58.47248          98.235758          81.824560
# min         0.00000           0.000000           0.000000
# 25%         7.00000           7.000000           4.000000
# ...

# %%
import seaborn as sns
sns.boxplot(
    data=df_nutritions)
# Out:
# <Axes: >

# %%
np.log1p(df_nutritions['calories']).hist()
# Out:
# <Axes: >

# %%
df_nutritions['total_fat_PDV'].quantile(0.96)
# Out:
# 129.0

# %%
df_nutritions['calories'].quantile(0.)
