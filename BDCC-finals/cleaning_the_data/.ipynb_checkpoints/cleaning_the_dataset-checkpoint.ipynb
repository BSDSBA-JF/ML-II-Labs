# %%
import os  # for file operations

from pyspark.sql import SparkSession
from pyspark.sql.types import (
    DoubleType,
    IntegerType,
    StringType,
    StructField,
    StructType,
    ArrayType,
)
from pyspark.sql.functions import (
    col,
    when,
    sum as spark_sum,
    round as spark_round,
    regexp_replace,
    split,
    udf,
    expr,
    explode,
)

from IPython.display import display, Markdown

# %% [markdown]
# # Setting our constants

# %%
ROOT_DIR = ""
PATH_PREFIX = "/mnt/data/public/insideairbnb/data.insideairbnb.com/"

START_DATE = "2019-01-01"
END_DATE = "2025-12-31"

CITY_CONFIGS = [
    {
        "label": "new-york-city",
        "root_path": f"{PATH_PREFIX}united-states/ny/new-york-city",
        "regex_key": "united-states/ny/new-york-city",
    },
    {
        "label": "los-angeles",
        "root_path": f"{PATH_PREFIX}united-states/ca/los-angeles",
        "regex_key": "united-states/ca/los-angeles",
    },
    {
        "label": "chicago",
        "root_path": f"{PATH_PREFIX}united-states/il/chicago",
        "regex_key": "united-states/tx/austin",
    },
]

# %% [markdown]
# # Loading the Dataset

# %% [markdown]
# The Inside Airbnb dataset is organized by month, so each city has a separate folder for every period. To analyze the data, we first need to gather all the months post-pandemic, which we have to define to be after 2021. For each month, we read `listings.csv` to get the price information and `listings.csv.gz` to get the amenities offered by each listing. The function `build_city_airbnb_df` combines all these months into a single Spark DataFrame for each city and save the combined data as a Parquet file for later use.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
import os

def load_city_files(city_config, start_year=2021, base_dir=PATH_PREFIX):
    spark = SparkSession.builder.appName(f"Airbnb_{city_config['label']}").getOrCreate()
    city_base_dir = os.path.join(base_dir, city_config["regex_key"])
    
    if not os.path.exists(city_base_dir):
        raise FileNotFoundError(f"Directory not found: {city_base_dir}")
    
    folders = [
        f for f in os.listdir(city_base_dir)
        if f[:4].isdigit() and int(f[:4]) >= 2021
    ]
    
    data_columns_to_keep = [
        "id",
        "number_of_reviews",
        "minimum_nights",
        "room_type",
        "latitude",
        "longitude",
        "property_type",
        "accommodates"
    ]
    
    viz_columns_to_keep = [
        "id",
        "price",
    ]
    
    df_data_list = []
    df_viz_list = []
    
    for folder in sorted(folders):
        month_path = os.path.join(city_base_dir, folder)
    
        data_filepath = os.path.join(month_path, "data/listings.csv.gz")
        viz_filepath = os.path.join(month_path, "visualisations/listings.csv")
    
        # --- Load DATA file as STRING columns ---
        if os.path.exists(data_filepath):
            df_data = spark.read.csv(data_filepath, header=True, inferSchema=False)
            df_data = df_data.select([col(c).cast("string") for c in data_columns_to_keep if c in df_data.columns])
            df_data_list.append(df_data)
    
        # --- Load VIZ file as STRING columns ---
        if os.path.exists(viz_filepath):
            df_viz = spark.read.csv(viz_filepath, header=True, inferSchema=False)
            df_viz = df_viz.select([col(c).cast("string") for c in viz_columns_to_keep if c in df_viz.columns])
            df_viz_list.append(df_viz)
    
    # --- Combine DATA ---
    df_data_combined = None
    if df_data_list:
        df_data_combined = df_data_list[0]
        for df in df_data_list[1:]:
            df_data_combined = df_data_combined.unionByName(df)
    
    # --- Combine VIZ ---
    df_viz_combined = None
    if df_viz_list:
        df_viz_combined = df_viz_list[0]
        for df in df_viz_list[1:]:
            df_viz_combined = df_viz_combined.unionByName(df)
    
    # --- JOIN ---
    return df_viz_combined.join(df_data_combined, on="id", how="left")

# %%
load_city_files(CITY_CONFIGS[1], start_year=2021).show()
# Out:
# +-------------------+-----+--------------------+--------------------+------------+--------------------+----------+--------------------+------------+
# |                 id|price|   number_of_reviews|      minimum_nights|   room_type|            latitude| longitude|       property_type|accommodates|
# +-------------------+-----+--------------------+--------------------+------------+--------------------+----------+--------------------+------------+
# |1035828230679193630|   48|                NULL|                NULL|        NULL|                NULL|      NULL|                NULL|        NULL|
# |1035828230679193630|   48|                NULL|                NULL|        NULL|                NULL|      NULL|                NULL|        NULL|
# |1035828230679193630|   48|                NULL|                NULL|        NULL|                NULL|      NULL|                NULL|        NULL|
# |1035828230679193630|   48|                NULL|                NULL|        NULL|                NULL|      NULL|                NULL|        NULL|
# |           10515317|  800|          ""Washer""|         ""Hangers""|Private room|             34.0928|-118.01985|Private room in h...|           1|
# |           10515317|  800|            ""Iron""| ""Fireplace guar...|Private room|             34.0928|-118.01985|Private room in h...|           1|
# |           10515317|  800| ""Dedicated work...|      ""Bed linens""|Private room|             34.0928|-118.01985|Private room in h...|           1|
# |           10515317|  800| ""Long term stay...| ""Patio or balco...|Private room|            34.09298|-118.01849|Private room in h...|           1|
# |           10515317|  800|            ""Wifi""| ""Ethernet conne...|Private room|            34.09298|-118.01849|Private room in h...|           1|
# |           10515317|  800| ""Air conditioni...|           ""Dryer""|Private room|            34.09298|-118.01849|Private room in h...|           1|
# |           10515317|  800|        ""Backyard""|       ""Microwave""|Private room|            34.09298|-118.01849|Private room in h...|           1|
# |           10515317|  800| ""Dishes and sil...|           ""Dryer""|Private room|            34.09298|-118.01849|Private room in r...|           1|
# |           10515317|  800|         ""Hangers""| ""Carbon monoxid...|Private room|            34.09298|-118.01849|Private room in home|           1|
# |           10515317|  800|      ""Rice maker""|       ""Hot water""|Private room|            34.09298|-118.01849|Private room in home|           1|
# |           10515317|  800| ""Long term stay...|         ""Kitchen""|Private room|            34.09298|-118.01849|Private room in home|           1|
# |           10515317|  800|   ""Self check-in""| ""Carbon monoxid...|Private room|            34.09298|-118.01849|Private room in home|           1|
# |           10515317|  800| ""Cleaning produ...|      ""Bed linens""|Private room|            34.09298|-118.01849|Private room in home|           1|
# |           10515317|  800| ""Carbon monoxid...| ""Dishes and sil...|Private room|            34.09298|-118.01849|Private room in home|           1|
# |             106061|   72|                   4|https://a0.muscac...|   Darrell E|https://a0.muscac...|    550078|https://www.airbn...|  2011-05-02|
# |             106061|   72|                   4|https://a0.muscac...|   Darrell E|https://a0.muscac...|    550078|https://www.airbn...|  2011-05-02|
# +-------------------+-----+--------------------+--------------------+------------+--------------------+----------+--------------------+------------+
# only showing top 20 rows

# %%
for city_config in CITY_CONFIGS:
    city_label = city_config['label']
    print(f"\n===== Processing {city_label} =====")

    # Clean folder name
    save_path = f"data/initial_join/{city_label.replace(' ', '_').lower()}"
    os.makedirs(save_path, exist_ok=True)  # ensure folder exists

    # Check if Parquet exists and has files
    parquet_exists = os.path.exists(save_path) and len(os.listdir(save_path)) > 0

    if not parquet_exists:
        # Load raw CSVs and save to Parquet
        df_city = load_city_files(city_config, start_year=2021)
        if df_city is not None:
            df_city.write.mode("overwrite").parquet(save_path)
            print(f"Saved {city_label} to {save_path} as Parquet.")
        else:
            print(f"No data for {city_label}, skipping.")
            continue

    # Load Parquet (either newly created or already existed)
    df_city = spark.read.parquet(save_path)
    df_city.show(5)
    print(f"Rows: {df_city.count():,}")
    print(f"Columns: {len(df_city.columns)}")
# Out:
# ===== Processing new-york-city =====
# +--------------------+---------+-----------------+--------------+---------+--------+---------+-------------+------------+
# |                  id|    price|number_of_reviews|minimum_nights|room_type|latitude|longitude|property_type|accommodates|
# +--------------------+---------+-----------------+--------------+---------+--------+---------+-------------+------------+
# |  A FAMILY OF TWO"""|        2|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# |  A FAMILY OF TWO"""|        2|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# |  A FAMILY OF TWO"""|       30|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# |            3 bdrms.|-73.94639|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# |            3 bdrms.|-73.94639|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# +--------------------+---------+-----------------+--------------+---------+--------+---------+-------------+------------+
# only showing top 5 rows
#
# Rows: 5,003,955
# Columns: 9
#
# ===== Processing los-angeles =====
# +--------------------+-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |                  id|price|number_of_reviews|minimum_nights|room_type|latitude|longitude|property_type|accommodates|
# +--------------------+-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |  LAX / Beach / f...|   30|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# | (11.8 M Disneyla...|    2|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# | (11.8 M Disneyla...|    2|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# | (11.8 M Disneyla...|    2|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# | (11.8 M Disneyla...|    2|             NULL|          NULL|     NULL|    NULL|     NULL|         NULL|        NULL|
# +--------------------+-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# only showing top 5 rows
#
# Rows: 4,405,045
# Columns: 9
#
# ===== Processing chicago =====
# +------+-----+-----------------+--------------------+---------------+--------+---------+-------------+------------+
# |    id|price|number_of_reviews|      minimum_nights|      room_type|latitude|longitude|property_type|accommodates|
# +------+-----+-----------------+--------------------+---------------+--------+---------+-------------+------------+
# |319887|  694|              4.0| ""Carbon monoxid...|Entire home/apt|30.25328|-97.72968|  Entire home|           5|
# |319887|  694|              4.0|           ""Dryer""|Entire home/apt|30.25328|-97.72968|  Entire home|           5|
# |319887|  694|              4.0|         ""Kitchen""|Entire home/apt|30.25328|-97.72968|  Entire home|           5|
# |319887|  694|                2|                   4|Entire home/apt|30.25328|-97.72968|  Entire home|           5|
# |319887|  694|              4.0| ""TV with standa...|Entire home/apt|30.25328|-97.72968|  Entire home|           5|
# +------+-----+-----------------+--------------------+---------------+--------+---------+-------------+------------+
# only showing top 5 rows
#
# Rows: 1,125,691
# Columns: 9

# %% [markdown]
# # Checking for Null Values

# %% [markdown]
# For each city, some listings have missing values, and since these rows are incomplete, they are not suitable for modeling. We therefore remove any listings with null values in either column to ensure a clean and reliable dataset.
#
# After this filtering:
# - New York City retains 355,392 listings (67% of the original dataset)
# - Los Angeles retains 380,924 listings (73%)
# - Chicago retains 103,685 listings (67%)
#
# These remaining datasets are sufficiently large to support robust analysis and predictive modeling.

# %%
for i, city in enumerate(CITY_CONFIGS):
    formal_name = city['label'].replace('-', ' ').title()
    print(formal_name)
    save_path = f"data/initial_join/{city_label.replace(' ', '_').lower()}"
    city_df = spark.read.parquet(save_path)
    total = city_df.count()
    remaining = city_df.dropna().count()
    print(f"Initial Size of {total} (100%)")
    print(f"Non-empty rows of {remaining} ({int(round(remaining/total, 2) * 100)}%).")
    total_rows = city_df.count()  # total number of rows
    
    na_counts_percentage = city_df.select(
        [
            (spark_round(
                1-(spark_sum(when(col(c).isNull(), 1).otherwise(0)) / total_rows),
                2
            ) * 100).alias(f'{c} (%)')
            for c in city_df.columns
        ]
    )
    
    display(na_counts_percentage.toPandas())
    display(Markdown(f'**Table 1{chr(97+i)}.** Percentage of Non-Null' 
                     f'Data Points for {formal_name}'))
    print('')
# Out:
# New York City
# Initial Size of 1125691 (100%)
# Non-empty rows of 694277 (62%).
#    id (%)  price (%)  number_of_reviews (%)  minimum_nights (%)  \
# 0   100.0       87.0                   76.0                76.0
#
#    room_type (%)  latitude (%)  longitude (%)  property_type (%)  \
# 0           76.0          76.0           76.0               76.0
#
#    accommodates (%)
# 0              76.0
# **Table 1a.** Percentage of Non-NullData Points for New York City
# Los Angeles
# Initial Size of 1125691 (100%)
# Non-empty rows of 694277 (62%).
#    id (%)  price (%)  number_of_reviews (%)  minimum_nights (%)  \
# 0   100.0       87.0                   76.0                76.0
#
#    room_type (%)  latitude (%)  longitude (%)  property_type (%)  \
# 0           76.0          76.0           76.0               76.0
#
#    accommodates (%)
# 0              76.0
# **Table 1b.** Percentage of Non-NullData Points for Los Angeles
# Chicago
# Initial Size of 1125691 (100%)
# Non-empty rows of 694277 (62%).
#    id (%)  price (%)  number_of_reviews (%)  minimum_nights (%)  \
# 0   100.0       87.0                   76.0                76.0
#
#    room_type (%)  latitude (%)  longitude (%)  property_type (%)  \
# 0           76.0          76.0           76.0               76.0
#
#    accommodates (%)
# 0              76.0
# **Table 1c.** Percentage of Non-NullData Points for Chicago

# %% [markdown]
# # Cleaning the amenities

# %% [markdown]
# We preprocessed Airbnb data for each city by first removing any rows with missing values and safely converting numeric columns to floats, dropping rows where conversion failed. Next, we encoded all categorical string columns using one-hot encoding while discarding the original string and intermediate index columns. Finally, the cleaned and transformed datasets were optionally saved as Parquet files for efficient storage and downstream analysis.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_replace, expr
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.ml import Pipeline
import os

def preprocess_city(city_config, save_parquet=True, output_dir="data/preprocessed"):
    """
    Preprocess city Airbnb data (before train/test split):
    1. Drop rows with any NULLs.
    2. Safely convert numeric columns to float (malformed entries become NULL then dropped).
    3. Drop 'id' column if present.
    """
    city_label = city_config['label']
    print(f"\n===== Processing {city_label} =====")
    uncleaned_path = f"data/initial_join/{city_label.replace(' ', '_').lower()}"
    df = spark.read.parquet(uncleaned_path)

    # --- Drop 'id' column if exists ---
    if 'id' in df.columns:
        df = df.drop('id')

    # --- Drop rows with any NULLs ---
    df = df.dropna(how='any')

    # --- List numeric columns ---
    numeric_cols = ["price", "number_of_reviews", "minimum_nights", "latitude", "longitude", "accommodates"]

    # --- Safely cast numeric columns ---
    for c in numeric_cols:
        if c in df.columns:
            df = df.withColumn(c, expr(f"try_cast(regexp_replace({c}, '\"', '') as float)"))

    # --- Drop any rows where numeric cast failed ---
    df = df.dropna(subset=numeric_cols)

    # --- Save parquet if requested ---
    filepath = f"{output_dir}/{city_label.replace(' ', '_').lower()}.parquet"
    if save_parquet:
        os.makedirs(output_dir, exist_ok=True)
        df.write.mode("overwrite").parquet(filepath)
        print(f"Saved preprocessed data for {city_label} → {filepath}")

    return df

# %%
spark.read.parquet(uncleaned_path).dropna().select('price').show()
# Out:
# +--------------------+
# |               price|
# +--------------------+
# |     ""Conditioner""|
# | ""Outdoor furnit...|
# |            ""Iron""|
# |    ""Coffee maker""|
# | ""Fire extinguis...|
# |    ""Coffee maker""|
# | ""Fire extinguis...|
# | ""Carbon monoxid...|
# | ""Cleaning produ...|
# |     ""Mini fridge""|
# |         ""Heating""|
# |              ""TV""|
# |              ""TV""|
# |              ""TV""|
# | ""Outdoor furnit...|
# | ""Outdoor furnit...|
# | ""Fire extinguis...|
# | ""Fire extinguis...|
# | ""Fire extinguis...|
# | ""Fire extinguis...|
# +--------------------+
# only showing top 20 rows

# %%
# from pyspark.sql import SparkSession
# from pyspark.sql.functions import col, regexp_replace, expr
# from pyspark.ml.feature import StringIndexer, OneHotEncoder
# from pyspark.ml import Pipeline
# import os

# spark = SparkSession.builder.getOrCreate()

# def preprocess_city(city_config, save_parquet=True, output_dir="data/preprocessed"):
#     """
#     Preprocess city Airbnb data:
#     1. Drop rows with any NULLs.
#     2. Safely convert numeric columns to float (malformed entries become NULL then dropped).
#     3. One-hot encode string/categorical columns.
#     """
#     city_label = city_config['label']
#     print(f"\n===== Processing {city_label} =====")
#     uncleaned_path = f"data/initial_join/{city_label.replace(' ', '_').lower()}"
#     df = spark.read.parquet(uncleaned_path)

#     # --- Drop rows with any NULLs ---
#     df = df.dropna(how='any')

#     # --- List numeric columns ---
#     numeric_cols = ["price", "number_of_reviews", "minimum_nights", "latitude", "longitude", "accommodates"]

#     # --- Safely cast numeric columns ---
#     for c in numeric_cols:
#         if c in df.columns:
#             # Remove quotes and extra spaces, then try cast
#             df = df.withColumn(c, expr(f"try_cast(regexp_replace({c}, '\"', '') as float)"))

#     # --- Drop any rows where numeric cast failed ---
#     df = df.dropna(subset=numeric_cols)

#     # --- Identify categorical/string columns ---
#     string_cols = ['room_type', 'property_type']

#     # --- Build one-hot encoding pipeline ---
#     indexers = [StringIndexer(inputCol=c, outputCol=c + "_idx", handleInvalid="keep") for c in string_cols]
#     encoders = [OneHotEncoder(inputCol=c + "_idx", outputCol=c + "_ohe") for c in string_cols]

#     pipeline = Pipeline(stages=indexers + encoders)
#     df_transformed = pipeline.fit(df).transform(df)

#     # --- Drop original string columns and indices ---
#     cols_to_drop = string_cols + [c + "_idx" for c in string_cols]
#     df_transformed = df_transformed.drop(*cols_to_drop)

#     # --- Save parquet ---
#     filepath = f"{output_dir}/{city_config['label']}.parquet"
#     if save_parquet:
#         os.makedirs(output_dir, exist_ok=True)
#         df_transformed.write.mode("overwrite").parquet(filepath)
#         print(f"Saved preprocessed data for {city_config['label']} → {filepath}")

#     return df_transformed

# %%
city_label
# Out:
# 'chicago'

# %%
city_label.replace(' ', '_').lower()
# Out:
# 'chicago'

# %%
df_preprocessed_dict
# Out:
# {'new-york-city': DataFrame[price: float, number_of_reviews: float, minimum_nights: float, room_type: string, latitude: float, longitude: float, property_type: string, accommodates: float],
#  'los-angeles': DataFrame[price: float, number_of_reviews: float, minimum_nights: float, room_type: string, latitude: float, longitude: float, property_type: string, accommodates: float],
#  'chicago': DataFrame[price: float, number_of_reviews: float, minimum_nights: float, room_type: string, latitude: float, longitude: float, property_type: string, accommodates: float]}

# %%
save_path
# Out:
# 'data/preprocessed/chicago'

# %%
spark.read.parquet('data/preprocessed/los-angeles.parquet').show()
# Out:
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |price|number_of_reviews|minimum_nights|room_type|latitude|longitude|property_type|accommodates|
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |  0.0|              5.0|           1.0|       30|    30.0|     30.0|           30|        30.0|
# |  0.0|              5.0|           0.0|       29|    29.0|    365.0|           29|       365.0|
# |  0.0|             4.67|           0.0|       30|    30.0|   1125.0|           30|      1125.0|
# | 30.0|              2.0|          60.0|       30|    30.0|   1125.0|           30|      1125.0|
# |  0.0|             10.0|           0.0|        1|     1.0|     30.0|            1|        30.0|
# |  0.0|             10.0|           0.0|        1|     1.0|     30.0|            1|        30.0|
# |  0.0|             10.0|           0.0|        1|     1.0|     30.0|            1|        30.0|
# |  0.0|             4.75|           0.0|       30|    30.0|     30.0|           30|        30.0|
# |  0.0|             4.75|           0.0|       30|    30.0|     30.0|           30|        30.0|
# |  0.0|             4.75|           0.0|       30|    30.0|     30.0|           30|        30.0|
# |  0.0|              9.0|           0.0|       30|    30.0|    365.0|           30|       365.0|
# |  0.0|              9.0|           0.0|       30|    30.0|    365.0|           30|       365.0|
# |  0.0|              9.0|           0.0|       30|    30.0|    365.0|           30|       365.0|
# |  0.0|              9.0|           0.0|       30|    30.0|    365.0|           30|       365.0|
# |  0.0|             4.71|           0.0|       30|    30.0|    365.0|           30|       365.0|
# |  0.0|             4.71|           0.0|       30|    30.0|    365.0|           30|       365.0|
# | 28.0|             4.71|          58.0|       30|    30.0|    365.0|           30|       365.0|
# |  0.0|             4.57|           0.0|      365|   365.0|     30.0|           30|       365.0|
# |  0.0|             4.57|           0.0|      365|   365.0|     30.0|           30|       365.0|
# | 30.0|             10.0|          60.0|       30|    30.0|   1125.0|           30|      1125.0|
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# only showing top 20 rows

# %%
df_preprocessed_dict = {}

# --- Run preprocessing for all cities ---
for city in CITY_CONFIGS:
    city_label = city_config['label']
    save_path = f"data/preprocessed/{city_label}"
    os.makedirs(save_path, exist_ok=True)  # ensure folder exists
    is_saved = os.path.exists(save_path)

    # Check if the preprocessed Parquet already exists
    if os.path.exists(save_path) and len(os.listdir(save_path)) == len(CITY_CONFIGS):
        df_preprocessed = preprocess_city(city)
        df_preprocessed.write.mode("overwrite").parquet(save_path)
        print(f"Saved {city_label} to {save_path} as Parquet.")
    else:
        df_preprocessed = spark.read.parquet(save_path)
    
    df_preprocessed_dict[city['label']] = df_preprocessed
    df_preprocessed.show(5, truncate=False)
# Out:
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |price|number_of_reviews|minimum_nights|room_type|latitude|longitude|property_type|accommodates|
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |0.0  |5.0              |0.0           |1125     |1125.0  |3.0      |3            |1125.0      |
# |60.0 |5.0              |89.0          |7        |7.0     |2.0      |2            |7.0         |
# |59.0 |5.0              |89.0          |7        |7.0     |2.0      |2            |7.0         |
# |0.0  |5.0              |0.0           |9        |9.0     |3.0      |3            |9.0         |
# |0.0  |4.88             |0.0           |2        |2.0     |60.0     |2            |60.0        |
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# only showing top 5 rows
#
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |price|number_of_reviews|minimum_nights|room_type|latitude|longitude|property_type|accommodates|
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |0.0  |5.0              |0.0           |1125     |1125.0  |3.0      |3            |1125.0      |
# |60.0 |5.0              |89.0          |7        |7.0     |2.0      |2            |7.0         |
# |59.0 |5.0              |89.0          |7        |7.0     |2.0      |2            |7.0         |
# |0.0  |5.0              |0.0           |9        |9.0     |3.0      |3            |9.0         |
# |0.0  |4.88             |0.0           |2        |2.0     |60.0     |2            |60.0        |
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# only showing top 5 rows
#
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |price|number_of_reviews|minimum_nights|room_type|latitude|longitude|property_type|accommodates|
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# |0.0  |5.0              |0.0           |1125     |1125.0  |3.0      |3            |1125.0      |
# |60.0 |5.0              |89.0          |7        |7.0     |2.0      |2            |7.0         |
# |59.0 |5.0              |89.0          |7        |7.0     |2.0      |2            |7.0         |
# |0.0  |5.0              |0.0           |9        |9.0     |3.0      |3            |9.0         |
# |0.0  |4.88             |0.0           |2        |2.0     |60.0     |2            |60.0        |
# +-----+-----------------+--------------+---------+--------+---------+-------------+------------+
# only showing top 5 rows

# %% [markdown]
# # Modeling

# %% [markdown]
# We will do modeling per city since as seen from our EDA, there is simpson's paradox present. So doing it per city would reflect a more accurate analysis. We will also test whether certain models can predict better on each city.

# %%
from typing import Any, Dict, Optional, Type, Union
import numpy as np
import pandas as pd

class ForecastingMetrics:
    """Class object that contains static methods for relevant
    forecasting metrics.

    Example Usage:
    --------------
    >>> from utils import ForecastingMetrics as forecast_metrics
    >>> forecast_metrics.mae(y_true, y_pred)
    """

    @staticmethod
    def mae(y_true: Union[np.ndarray, pd.Series], y_pred: Union[np.ndarray, pd.Series]) -> np.float32:
        return np.float32(np.mean(np.abs(y_true - y_pred)))

    @staticmethod
    def mse(y_true: Union[np.ndarray, pd.Series], y_pred: Union[np.ndarray, pd.Series]) -> np.float32:
        return np.float32(np.mean((y_true - y_pred) ** 2))

    @staticmethod
    def rmse(y_true: Union[np.ndarray, pd.Series], y_pred: Union[np.ndarray, pd.Series]) -> np.float32:
        return np.float32(np.sqrt(np.mean((y_true - y_pred) ** 2)))

    @staticmethod
    def mape(y_true: Union[np.ndarray, pd.Series], y_pred: Union[np.ndarray, pd.Series]) -> np.float32:
        y_true = np.asarray(y_true)
        y_pred = np.asarray(y_pred)
        nonzero_filter = y_true != 0
        y_true = y_true[nonzero_filter]
        y_pred = y_pred[nonzero_filter]
        return np.float32(np.mean(np.abs((y_true - y_pred) / y_true)) * 100)

    @staticmethod
    def smape(y_true: Union[np.ndarray, pd.Series], y_pred: Union[np.ndarray, pd.Series]) -> np.float32:
        numerator = np.abs(y_true - y_pred)
        denominator = np.abs(y_true) + np.abs(y_pred)
        nonzero_filter = denominator != 0
        return np.float32(np.mean(numerator[nonzero_filter] / (denominator[nonzero_filter] / 2)) * 100)

    @staticmethod
    def r2(y_true: Union[np.ndarray, pd.Series], y_pred: Union[np.ndarray, pd.Series]) -> np.float32:
        """Compute R-squared (coefficient of determination)."""
        y_true = np.asarray(y_true)
        y_pred = np.asarray(y_pred)
        ss_res = np.sum((y_true - y_pred) ** 2)
        ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
        return np.float32(1 - ss_res / ss_tot)

    @classmethod
    def compute_all_metrics(cls, y_true: Union[np.ndarray, pd.Series], y_pred: Union[np.ndarray, pd.Series]) -> Dict[str, np.float32]:
        return {
            "MAE": cls.mae(y_true, y_pred),
            "MSE": cls.mse(y_true, y_pred),
            "RMSE": cls.rmse(y_true, y_pred),
            "MAPE": cls.mape(y_true, y_pred),
            "SMAPE": cls.smape(y_true, y_pred),
            "R2": cls.r2(y_true, y_pred),
        }

# %% [markdown]
# ## Baseline: Linear Regression

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.sql.functions import col
import numpy as np

# Assume df_preprocessed_dict contains preprocessed DataFrames per city
# Example: df_preprocessed_dict = {"new-york-city": df_nyc, "los-angeles": df_la, ...}

train_dfs = {}
test_dfs = {}

# --- Train/Test Split per city ---
for city_name, df in df_preprocessed_dict.items():
    print(f"Splitting train/test for {city_name}...")
    train_df, test_df = df.randomSplit([0.8, 0.2], seed=42)
    train_dfs[city_name] = train_df
    test_dfs[city_name] = test_df

# --- Linear Regression ---
lr_models = {}
lr_predictions = {}

for city_name in train_dfs.keys():
    print(f"\nTraining Linear Regression for {city_name}")
    
    # --- Assemble features ---
    # Exclude target 'price' and vector columns
    numeric_features = [
        c for c in train_dfs[city_name].columns 
        if c != "price" and not c.endswith("_ohe")
    ]
    
    assembler = VectorAssembler(
        inputCols=numeric_features,
        outputCol="features"
    )
    
    train_features = assembler.transform(train_dfs[city_name]).select(
        "features", col("price").alias("label")
    )
    test_features = assembler.transform(test_dfs[city_name]).select(
        "features", col("price").alias("label")
    )
    
    # --- Train Linear Regression ---
    lr = LinearRegression(featuresCol="features", labelCol="label")
    lr_model = lr.fit(train_features)
    lr_models[city_name] = lr_model
    
    # --- Predict on test set ---
    preds = lr_model.transform(test_features)
    lr_predictions[city_name] = preds
    
    # --- Show example predictions ---
    print(f"Example predictions for {city_name}:")
    preds.select("features", "label", "prediction").show(5, truncate=False)
    
    # --- Compute metrics (using numpy arrays) ---
    y_true = np.array([row['label'] for row in preds.select("label").collect()])
    y_pred = np.array([row['prediction'] for row in preds.select("prediction").collect()])
    
    # Assuming ForecastingMetrics.compute_all_metrics exists
    metrics = ForecastingMetrics.compute_all_metrics(y_true, y_pred)
    print(metrics)
# Out:
# Splitting train/test for new-york-city...
# Splitting train/test for los-angeles...
# Splitting train/test for chicago...
#
# Training Linear Regression for new-york-city
# Example predictions for new-york-city:
# +-----------------------------+-----+------------------+
# |features                     |label|prediction        |
# +-----------------------------+-----+------------------+
# |[8.0,0.0,30.0,31.0,31.0]     |0.0  |1.4542494704501918|
# |[9.0,0.0,30.0,1125.0,1125.0] |0.0  |1.5913710240412071|
# |[9.0,0.0,30.0,1125.0,1125.0] |0.0  |1.5913710240412071|
# |[10.0,0.0,7.0,14.0,14.0]     |0.0  |1.511188483029327 |
# |[10.0,0.0,30.0,1125.0,1125.0]|0.0  |1.61756854847597  |
# +-----------------------------+-----+------------------+
# only showing top 5 rows
#
# {'MAE': 4.176504, 'MSE': 53.561047, 'RMSE': 7.318541, 'MAPE': 164.971, 'SMAPE': 160.91779, 'R2': 0.75586104}
#
# Training Linear Regression for los-angeles
# Example predictions for los-angeles:
# +-----------------------------+-----+------------------+
# |features                     |label|prediction        |
# +-----------------------------+-----+------------------+
# |[10.0,0.0,1.0,7.0,7.0]       |0.0  |2.724323754029744 |
# |[8.0,54.0,2.0,29.0,29.0]     |24.0 |15.715136815654411|
# |[9.0,60.0,30.0,1125.0,1125.0]|30.0 |21.65253130941098 |
# |[9.0,0.0,30.0,365.0,365.0]   |0.0  |3.958608023412874 |
# |[10.0,0.0,3.0,1125.0,1125.0] |0.0  |6.817921300046094 |
# +-----------------------------+-----+------------------+
# only showing top 5 rows
#
# {'MAE': 7.683544, 'MSE': 116.70847, 'RMSE': 10.803169, 'MAPE': 60.722225, 'SMAPE': 112.94513, 'R2': 0.76713353}
#
# Training Linear Regression for chicago
# Example predictions for chicago:
# +---------------------------------------+-----+--------------------+
# |features                               |label|prediction          |
# +---------------------------------------+-----+--------------------+
# |[10.0,57.0,3.0,14.0,14.0]              |27.0 |29.146978075684228  |
# |[9.0,0.0,1.0,4.0,4.0]                  |0.0  |0.7515714502897071  |
# |[10.0,0.0,3.0,1125.0,1125.0]           |0.0  |-0.32626410506770176|
# |[4.800000190734863,28.0,3.0,8.0,1125.0]|7.0  |13.762814962414982  |
# |[4.53000020980835,52.0,2.0,365.0,365.0]|25.0 |24.51449819218445   |
# +---------------------------------------+-----+--------------------+
# only showing top 5 rows
#
# {'MAE': 1.9449984, 'MSE': 10.795603, 'RMSE': 3.2856662, 'MAPE': 24.570076, 'SMAPE': 81.2363, 'R2': 0.9302464}

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.functions import col
import numpy as np

# Dictionaries to store results
lr_models = {}
lr_predictions_train = {}
lr_predictions_test = {}
metrics_train = {}
metrics_test = {}

for city_name, df in df_preprocessed_dict.items():
    print(f"\nProcessing {city_name}...")

    # --- Train/Test Split ---
    train_df, test_df = df.randomSplit([0.8, 0.2], seed=42)

    # --- Assemble features ---
    numeric_features = [c for c in df.columns if c != "price" and not c.endswith("_ohe")]
    assembler = VectorAssembler(inputCols=numeric_features, outputCol="features")

    train_features = assembler.transform(train_df).select("features", col("price").alias("label"))
    test_features = assembler.transform(test_df).select("features", col("price").alias("label"))

    # --- Define Linear Regression ---
    lr = LinearRegression(featuresCol="features", labelCol="label")

    # --- Hyperparameter grid ---
    paramGrid = ParamGridBuilder() \
        .addGrid(lr.regParam, [0.0, 0.1, 1, 10]) \
        .addGrid(lr.elasticNetParam, [1.0]) \
        .addGrid(lr.maxIter, [50]) \
        .build()


    # --- Evaluator ---
    evaluator = RegressionEvaluator(labelCol="label", predictionCol="prediction", metricName="rmse")

    # --- CrossValidator ---
    cv = CrossValidator(estimator=lr,
                        estimatorParamMaps=paramGrid,
                        evaluator=evaluator,
                        numFolds=3,
                        parallelism=2)  # adjust parallelism if needed

    # --- Train model with CV ---
    cv_model = cv.fit(train_features)
    best_model = cv_model.bestModel
    lr_models[city_name] = best_model

    # --- Predictions ---
    preds_train = best_model.transform(train_features)
    preds_test = best_model.transform(test_features)
    
    lr_predictions_train[city_name] = preds_train
    lr_predictions_test[city_name] = preds_test

    # --- Compute metrics for train set ---
    y_train_true = np.array([row['label'] for row in preds_train.select("label").collect()])
    y_train_pred = np.array([row['prediction'] for row in preds_train.select("prediction").collect()])
    metrics_train[city_name] = ForecastingMetrics.compute_all_metrics(y_train_true, y_train_pred)

    # --- Compute metrics for test set ---
    y_test_true = np.array([row['label'] for row in preds_test.select("label").collect()])
    y_test_pred = np.array([row['prediction'] for row in preds_test.select("prediction").collect()])
    metrics_test[city_name] = ForecastingMetrics.compute_all_metrics(y_test_true, y_test_pred)

    print(f"Best hyperparameters for {city_name}:")
    print(f"  regParam: {best_model._java_obj.getRegParam()}")
    print(f"  elasticNetParam: {best_model._java_obj.getElasticNetParam()}")
    print(f"  maxIter: {best_model._java_obj.getMaxIter()}")

    print(f"Train metrics for {city_name}: {metrics_train[city_name]}")
    print(f"Test metrics for {city_name}: {metrics_test[city_name]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 15
#      12 metrics_train = {}
#      13 metrics_test = {}
# ---> 15 for city_name, df in df_preprocessed_dict.items():
#      16     print(f"\nProcessing {city_name}...")
#      18     # --- Train/Test Split ---
#
# NameError: name 'df_preprocessed_dict' is not defined
